# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaQuezia-yay/Tarefins/blob/main/Istudar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = (input("Digite a senha: "))

while senha != "IA_2026":
    print(f" {senha} Senha incorreta. Tente novamente")
    senha = (input("Digite a senha novamente: "))

    print(f"{senha} Senha correta")
# Out:
# Digite a senha: yhngfd
#  yhngfd Senha incorreta. Tente novamente
# Digite a senha novamente: nhmjjfdunm
# nhmjjfdunm Senha correta
#  nhmjjfdunm Senha incorreta. Tente novamente
# Digite a senha novamente: 8757767
# 8757767 Senha correta
#  8757767 Senha incorreta. Tente novamente
# Digite a senha novamente: jhhhhhj
# jhhhhhj Senha correta
#  jhhhhhj Senha incorreta. Tente novamente
# Digite a senha novamente: IA_2026
# IA_2026 Senha correta

# %% [markdown]
# ........................................................................

# %%
pontuacao = int(input("Digite a pontuação do modelo (Entre 0 até 100): "))

if pontuacao >= 90 and pontuacao <=100:
  print("Classeficação: Excelente, com o total de", pontuacao, "Pontos")

elif pontuacao >= 70 and pontuacao <= 89:
  print("Clasificação: Estável, com total de", pontuacao, "Pontos")

elif pontuacao >=0 and pontuacao <=69:
  print("Classificação: Em treinamento, com o total de", pontuacao, "Pontos")

elif pontuacao < 0:
  print("Número negativo? ... É SERIO?!?!?! >:/ ")

else:
  print("Que Djabo de numero que você digitou???????? E só de 0 a 100 carai >:/ ")
# Out:
# Digite a pontuação do modelo (Entre 0 até 100): 98
# Classeficação: Excelente, com o total de 98 Pontos
